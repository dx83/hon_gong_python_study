# %%
import pandas as pd
dict_data = {'a':1, 'b':2, 'c':3}
sr = pd.Series(dict_data)

type(sr)
# Out:
# pandas.core.series.Series

# %%
sr
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
list_data = ['2018-01-02', 3.14, 'ABC', 100, True]
sr = pd.Series(list_data)
sr
# Out:
# 0    2018-01-02
# 1          3.14
# 2           ABC
# 3           100
# 4          True
# dtype: object

# %%
idx = sr.index
idx
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
val = sr.values
val
# Out:
# array(['2018-01-02', 3.14, 'ABC', 100, True], dtype=object)

# %%
tup_data = ('영인', '2010-05-01', '여', True)
sr = pd.Series(tup_data, index=['이름', '생년월일', '성별', '학생여부'])
sr
# Out:
# 이름              영인
# 생년월일    2010-05-01
# 성별               여
# 학생여부          True
# dtype: object

# %%
sr.iloc[0]
# Out:
# '영인'

# %%
sr['이름']
# Out:
# '영인'

# %%
sr.iloc[[1,2]]
# Out:
# 생년월일    2010-05-01
# 성별               여
# dtype: object

# %%
sr[['생년월일', '성별']]
# Out:
# 생년월일    2010-05-01
# 성별               여
# dtype: object

# %%
sr.iloc[0:3]
# Out:
# 이름              영인
# 생년월일    2010-05-01
# 성별               여
# dtype: object

# %%
sr['이름':'성별']
# Out:
# 이름              영인
# 생년월일    2010-05-01
# 성별               여
# dtype: object
