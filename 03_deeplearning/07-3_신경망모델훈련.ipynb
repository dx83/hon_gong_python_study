# %%
import keras
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()

# %%
from sklearn.model_selection import train_test_split
x_train_scaled = x_train / 255.0
x_train_scaled, z_scaled, y_train, z_train = train_test_split(x_train_scaled, y_train, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Flatten
model = Sequential([
    Input(shape=(28,28)),
    Flatten(),
    Dense(100, activation='relu'),
    Dense(10, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 100)            │        78,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 79,510 (310.59 KB)
#  Trainable params: 79,510 (310.59 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train_scaled, y_train, epochs=5, verbose=0)

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss'])

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Flatten
model = Sequential([
    Input(shape=(28,28)),
    Flatten(),
    Dense(100, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train_scaled, y_train, epochs=20, verbose=2)
# Out:
# Epoch 1/20
# 1500/1500 - 2s - 1ms/step - accuracy: 0.8115 - loss: 0.5316
# Epoch 2/20
# 1500/1500 - 2s - 1ms/step - accuracy: 0.8594 - loss: 0.3895
# Epoch 3/20
# 1500/1500 - 2s - 1ms/step - accuracy: 0.8738 - loss: 0.3506
# Epoch 4/20
# 1500/1500 - 2s - 1ms/step - accuracy: 0.8821 - loss: 0.3284
# Epoch 5/20
# 1500/1500 - 2s - 1ms/step - accuracy: 0.8884 - loss: 0.3143
# Epoch 6/20
# 1500/1500 - 2s - 1ms/step - accuracy: 0.8919 - loss: 0.3018
# Epoch 7/20
# 1500/1500 - 2s - 1ms/step - accuracy: 0.8946 - loss: 0.2922
# Epoch 8/20
# 1500/1500 - 2s - 1ms/step - accuracy: 0.8987 - loss: 0.2867
# Epoch 9/20
# 1500/1500 - 2s - 1ms/step - accuracy: 0.9002 - loss: 0.2785
# Epoch 10/20
# 1500/1500 - 2s - 1ms/step - accuracy: 0.9051 - loss: 0.2718
# Epoch 11/20
# 1500/1500 - 2s - 1ms/step - accuracy: 0.9074 - loss: 0.2639
# Epoch 12/20
# 1500/1500 - 2s - 1ms/step - accuracy: 0.9112 - loss: 0.2586
# Epoch 13/20
# 1500/1500 - 2s - 1ms/step - accuracy: 0.9118 - loss: 0.2532
# Epoch 14/20
# ...

# %%
plt.plot(history.history['loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Flatten, Dropout
model = Sequential([
    Input(shape=(28,28)),
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.3),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train_scaled, y_train, validation_data=(z_scaled, z_train), epochs=20, verbose=2)
# Out:
# Epoch 1/20
# 1500/1500 - 3s - 2ms/step - accuracy: 0.7915 - loss: 0.5887 - val_accuracy: 0.8467 - val_loss: 0.4229
# Epoch 2/20
# 1500/1500 - 2s - 2ms/step - accuracy: 0.8444 - loss: 0.4350 - val_accuracy: 0.8508 - val_loss: 0.4023
# Epoch 3/20
# 1500/1500 - 2s - 2ms/step - accuracy: 0.8550 - loss: 0.4037 - val_accuracy: 0.8622 - val_loss: 0.3751
# Epoch 4/20
# 1500/1500 - 2s - 1ms/step - accuracy: 0.8607 - loss: 0.3828 - val_accuracy: 0.8717 - val_loss: 0.3543
# Epoch 5/20
# 1500/1500 - 2s - 2ms/step - accuracy: 0.8668 - loss: 0.3645 - val_accuracy: 0.8736 - val_loss: 0.3441
# Epoch 6/20
# 1500/1500 - 2s - 2ms/step - accuracy: 0.8724 - loss: 0.3514 - val_accuracy: 0.8742 - val_loss: 0.3480
# Epoch 7/20
# 1500/1500 - 2s - 2ms/step - accuracy: 0.8747 - loss: 0.3413 - val_accuracy: 0.8776 - val_loss: 0.3348
# Epoch 8/20
# 1500/1500 - 2s - 2ms/step - accuracy: 0.8759 - loss: 0.3340 - val_accuracy: 0.8794 - val_loss: 0.3345
# Epoch 9/20
# ...

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Flatten, Dropout
model = Sequential([
    Input(shape=(28,28)),
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.3),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train_scaled, y_train, validation_data=(z_scaled, z_train), epochs=11, verbose=2)
# Out:
# Epoch 1/11
# 1500/1500 - 3s - 2ms/step - accuracy: 0.7964 - loss: 0.5872 - val_accuracy: 0.8430 - val_loss: 0.4405
# Epoch 2/11
# 1500/1500 - 2s - 1ms/step - accuracy: 0.8409 - loss: 0.4375 - val_accuracy: 0.8598 - val_loss: 0.3824
# Epoch 3/11
# 1500/1500 - 2s - 2ms/step - accuracy: 0.8509 - loss: 0.4067 - val_accuracy: 0.8668 - val_loss: 0.3603
# Epoch 4/11
# 1500/1500 - 2s - 1ms/step - accuracy: 0.8614 - loss: 0.3801 - val_accuracy: 0.8734 - val_loss: 0.3477
# Epoch 5/11
# 1500/1500 - 2s - 1ms/step - accuracy: 0.8646 - loss: 0.3670 - val_accuracy: 0.8762 - val_loss: 0.3377
# Epoch 6/11
# 1500/1500 - 2s - 2ms/step - accuracy: 0.8705 - loss: 0.3497 - val_accuracy: 0.8735 - val_loss: 0.3399
# Epoch 7/11
# 1500/1500 - 2s - 2ms/step - accuracy: 0.8742 - loss: 0.3435 - val_accuracy: 0.8775 - val_loss: 0.3354
# Epoch 8/11
# 1500/1500 - 2s - 2ms/step - accuracy: 0.8760 - loss: 0.3329 - val_accuracy: 0.8799 - val_loss: 0.3301
# Epoch 9/11
# ...

# %%
model.save('model-whole.keras')

# %%
model = keras.models.load_model('model-whole.keras')
model.evaluate(z_scaled, z_train)
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8844 - loss: 0.3204
# [0.3204439878463745, 0.8844166398048401]
